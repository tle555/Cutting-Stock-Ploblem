# %%
pip install pulp
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting pulp
#   Downloading PuLP-2.7.0-py3-none-any.whl (14.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.3/14.3 MB 70.3 MB/s eta 0:00:00
# Installing collected packages: pulp
# Successfully installed pulp-2.7.0

# %% [markdown]
# #รปเเบบการตัดเหล็กราง

# %%
length = [1995, 1950, 2075, 2332]
L = 6050

n = [int(L/x) for x in length]
m = [L - j*length[i] for i,j in enumerate(n)]

print(f'จำนวนชิ้นงานเริ่มต้น :{n}')
print(f'เศษเหลือเริ่มต้น : {m}')

for i, j in enumerate(length): 
  for x in range(n[i], 0, -1):
    print(f':: index = {i} ความยาวชิ้นงาน = {j}  จำนวนชิ้นที่ตัด = {x}  เศษเหลือ = {L - x*j}')
    for a, b in enumerate(length):
      if a != i:
        for y in range(1, n[a]):
          if L - x*j >= b*y:
            print('>>', y,"ชิ้น",b,"mm","เศษเหลือ =", L - x*j - b*y) 
            for c, d in enumerate(length):
              if c != i:
                for z in range(1, n[c]): 
                  if  L - x*j - b*y >=  d*z :
                    print('>>>', z,"ชิ้น",d,"mm","เศษเหลือ =", L - x*j - b*y-d*z)
# Out:
# จำนวนชิ้นงานเริ่มต้น :[3, 3, 2, 2]
# เศษเหลือเริ่มต้น : [65, 200, 1900, 1386]
# :: index = 0 ความยาวชิ้นงาน = 1995  จำนวนชิ้นที่ตัด = 3  เศษเหลือ = 65
# :: index = 0 ความยาวชิ้นงาน = 1995  จำนวนชิ้นที่ตัด = 2  เศษเหลือ = 2060
# >> 1 ชิ้น 1950 mm เศษเหลือ = 110
# :: index = 0 ความยาวชิ้นงาน = 1995  จำนวนชิ้นที่ตัด = 1  เศษเหลือ = 4055
# >> 1 ชิ้น 1950 mm เศษเหลือ = 2105
# >>> 1 ชิ้น 1950 mm เศษเหลือ = 155
# >>> 1 ชิ้น 2075 mm เศษเหลือ = 30
# >> 2 ชิ้น 1950 mm เศษเหลือ = 155
# >> 1 ชิ้น 2075 mm เศษเหลือ = 1980
# >>> 1 ชิ้น 1950 mm เศษเหลือ = 30
# >> 1 ชิ้น 2332 mm เศษเหลือ = 1723
# :: index = 1 ความยาวชิ้นงาน = 1950  จำนวนชิ้นที่ตัด = 3  เศษเหลือ = 200
# :: index = 1 ความยาวชิ้นงาน = 1950  จำนวนชิ้นที่ตัด = 2  เศษเหลือ = 2150
# >> 1 ชิ้น 1995 mm เศษเหลือ = 155
# >> 1 ชิ้น 2075 mm เศษเหลือ = 75
# :: index = 1 ความยาวชิ้นงาน = 1950  จำนวนชิ้นที่ตัด = 1  เศษเหลือ = 4100
# >> 1 ชิ้น 1995 mm เศษเหลือ = 2105
# >>> 1 ชิ้น 1995 mm เศษเหลือ = 110
# >>> 1 ชิ้น 2075 mm เศษเหลือ = 30
# >> 2 ชิ้น 1995 mm เศษเหลือ = 110
# >> 1 ชิ้น 2075 mm เศษเหลือ = 2025
# >>> 1 ชิ้น 1995 mm เศษเหลือ = 30
# >> 1 ชิ้น 2332 mm เศษเหลือ = 1768
# :: index = 2 ความยาวชิ้นงาน = 2075  จำนวนชิ้นที่ตัด = 2  เศษเหลือ = 1900
# :: index = 2 ความยาวชิ้นงาน = 2075  จำนวนชิ้นที่ตัด = 1  เศษเหลือ = 3975
# >> 1 ชิ้น 1995 mm เศษเหลือ = 1980
# >>> 1 ชิ้น 1950 mm เศษเหลือ = 30
# >> 1 ชิ้น 1950 mm เศษเหลือ = 2025
# >>> 1 ชิ้น 1995 mm เศษเหลือ = 30
# >>> 1 ชิ้น 1950 mm เศษเหลือ = 75
# >> 2 ชิ้น 1950 mm เศษเหลือ = 75
# >> 1 ชิ้น 2332 mm เศษเหลือ = 1643
# :: index = 3 ความยาวชิ้นงาน = 2332  จำนวนชิ้นที่ตัด = 2  เศษเหลือ = 1386
# :: index = 3 ความยาวชิ้นงาน = 2332  จำนวนชิ้นที่ตัด = 1  เศษเหลือ = 3718
# >> 1 ชิ้น 1995 mm เศษเหลือ = 1723
# >> 1 ชิ้น 1950 mm เศษเหลือ = 1768
# >> 1 ชิ้น 2075 mm เศษเหลือ = 1643

# %% [markdown]
# #เหล็กราง

# %%
# (new) Min Cost เหล็กราง
from pulp import *  
import pandas as pd 
import numpy as np 

#set
pattern = ["pattern1","pattern2","pattern3","pattern4","pattern5","pattern6","pattern7","pattern8","pattern9","patterna","patternb"]
name_work = ["202-05","205-05","210-05","240-17"]

#parameter
unitcost_steel =int(input("unitcost_steel:"))
length ={"202-05":1995,"205-05":1950, "210-05":2075,"240-17":2332}

demand= {
    "202-05" : int(input("Demand 202-05 :")) ,
    "205-05" : int(input("Demand 205-05 :")) ,
    "210-05" : int(input("Demand 210-05 :")),
    "240-17" : int(input("Demand 240-17 :"))
}
work_piece ={
     "pattern1":{"202-05": 3 ,"205-05":0 ,"210-05":0 ,"240-17":0},

    "pattern2":{"202-05":2 ,"205-05":1 ,"210-05":0 ,"240-17":0},

    "pattern3":{"202-05":1 ,"205-05":1 ,"210-05":1 ,"240-17":0},

    "pattern4":{"202-05":1 ,"205-05":2 ,"210-05":0 ,"240-17":0},

    "pattern5":{"202-05":0 ,"205-05":3 ,"210-05":0 ,"240-17":0},

    "pattern6":{"202-05":0 ,"205-05":0 ,"210-05":2 ,"240-17":0},

    "pattern7":{"202-05":0 ,"205-05":0 ,"210-05":1 ,"240-17":1},

    "pattern8":{"202-05":0 ,"205-05":0 ,"210-05":0 ,"240-17":2},

    "pattern9":{"202-05":1 ,"205-05":0 ,"210-05":0 ,"240-17":1},

    "patterna":{"202-05":0 ,"205-05":2 ,"210-05":1 ,"240-17":0},
    
    "patternb":{"202-05":0 ,"205-05":1 ,"210-05":0 ,"240-17":1}

 }

loss_pattern = {
    "pattern1":65  ,
    "pattern2":110 ,
    "pattern3":30  ,
    "pattern4":155 ,
    "pattern5":200 ,
    "pattern6":1900 ,
    "pattern7":1643 ,
    "pattern8":1386 ,
    "pattern9":1732 ,
    "patterna":75 ,
    "patternb":1768 
}

#name_plomblem_minimize
model =LpProblem("Cutting Stock_U" ,LpMinimize)

#decision variable
x =LpVariable.dict("x",pattern,lowBound=0 ,cat =LpInteger)

#objective function
model += lpSum(x[i]*unitcost_steel for i in pattern)
#model += lpSum(x[i]*loss_pattern[i] for i in pattern)

#constrain
for j in name_work : 
  model += lpSum(x[i]*work_piece[i][j] for i in pattern) >=demand[j] #เงื่อนไขผลิตงานให้ได้มากกว่าหรือเท่ากับdemand

#solve
model.solve()
print(model)
print("Status Model:",LpStatus[model.status]) #check status model
print("Opjective Funtion [Min_Cost]  = " , value(model.objective) ,"Baht") #เเสดงค่าobjective function

#เเสดงค่าdecision variabe
sum=0
for v in model.variables():
  if v.varValue > 0 : 
    print("Cutting" ,v.name,"=",v.varValue,"เส้น")
    sum =sum +v.varValue  
print("Total Steel = " ,sum,"เส้น")

d=[] #list decistion variable
for v in model.variables():
   d.append(v.varValue )
w=np.array(d)

l=[] #list loss_pattern
for i in loss_pattern.values():
  l.append(i)
q=np.array(l)

print("Total Loss =",np.sum(w*q),"mm") #เเสดงค่า loss

#เก็บlistชิ้นงาน

p1=[]
p2=[]
p3=[]
p4=[]

for i in work_piece.values():
  p1.append(i["202-05"])
  p2.append(i["205-05"])
  p3.append(i["210-05"])
  p4.append(i["240-17"])

p_202_05 =np.array(p1)
p_205_05 =np.array(p2)
p_210_05 =np.array(p3)
p_240_17 =np.array(p4)

#เเสดงค่าจำนวนชิ้นงาน
print("Number of [202-05] =",np.sum(p_202_05*w),"pieces" )
print("Number of [205-05] =",np.sum(p_205_05*w),"pieces")
print("Number of [210-05] =",np.sum(p_210_05*w),"pieces" )
print("Number of [240-17] =",np.sum(p_240_17*w),"pieces" )
# Out:
# unitcost_steel:5
# Demand 202-05 :5
# Demand 205-05 :5
# Demand 210-05 :5
# Demand 240-17 :5
# Cutting_Stock_U:
# MINIMIZE
# 5*x_pattern1 + 5*x_pattern2 + 5*x_pattern3 + 5*x_pattern4 + 5*x_pattern5 + 5*x_pattern6 + 5*x_pattern7 + 5*x_pattern8 + 5*x_pattern9 + 5*x_patterna + 5*x_patternb + 0
# SUBJECT TO
# _C1: 3 x_pattern1 + 2 x_pattern2 + x_pattern3 + x_pattern4 + x_pattern9 >= 5
#
# _C2: x_pattern2 + x_pattern3 + 2 x_pattern4 + 3 x_pattern5 + 2 x_patterna
#  + x_patternb >= 5
#
# _C3: x_pattern3 + 2 x_pattern6 + x_pattern7 + x_patterna >= 5
#
# _C4: x_pattern7 + 2 x_pattern8 + x_pattern9 + x_patternb >= 5
#
# VARIABLES
# 0 <= x_pattern1 Integer
# 0 <= x_pattern2 Integer
# 0 <= x_pattern3 Integer
# 0 <= x_pattern4 Integer
# 0 <= x_pattern5 Integer
# 0 <= x_pattern6 Integer
# 0 <= x_pattern7 Integer
# 0 <= x_pattern8 Integer
# 0 <= x_pattern9 Integer
# 0 <= x_patterna Integer
# 0 <= x_patternb Integer
#
# Status Model: Optimal
# Opjective Funtion [Min_Cost]  =  40.0 Baht
# Cutting x_pattern3 = 5.0 เส้น
# Cutting x_pattern7 = 1.0 เส้น
# Cutting x_pattern8 = 2.0 เส้น
# Total Steel =  8.0 เส้น
# Total Loss = 4565.0 mm
# Number of [202-05] = 5.0 pieces
# Number of [205-05] = 5.0 pieces
# Number of [210-05] = 6.0 pieces
# Number of [240-17] = 5.0 pieces

# %%
#(ole) Min Cost เหล็กราง 
from pulp import *  
import pandas as pd 
import numpy as np 

#set
pattern = ["pattern1","pattern2","pattern3","pattern4","pattern5","pattern6","pattern7","pattern8"]
name_work = ["202-05","205-05","210-05","240-17"]

#parameter
unitcost_steel =int(input("unitcost_steel:"))
length ={"202-05":1995,"205-05":1950, "210-05":2075,"240-17":2332}

demand= {
    "202-05" : int(input("Demand 202-05 :")) ,
    "205-05" : int(input("Demand 205-05 :")) ,
    "210-05" : int(input("Demand 210-05 :")),
    "240-17" : int(input("Demand 240-17 :"))
}
work_piece ={
    "pattern1":{"202-05":3 ,"205-05":0 ,"210-05":0 ,"240-17":0},

    "pattern2":{"202-05":2 ,"205-05":1 ,"210-05":0 ,"240-17":0},

    "pattern3":{"202-05":1 ,"205-05":1 ,"210-05":1 ,"240-17":0},

    "pattern4":{"202-05":1 ,"205-05":2 ,"210-05":0 ,"240-17":0},

    "pattern5":{"202-05":0 ,"205-05":3 ,"210-05":0 ,"240-17":0},

    "pattern6":{"202-05":0 ,"205-05":0 ,"210-05":2 ,"240-17":0},

    "pattern7":{"202-05":0 ,"205-05":0 ,"210-05":1 ,"240-17":1},

    "pattern8":{"202-05":0 ,"205-05":0 ,"210-05":0 ,"240-17":2}
 }

loss_pattern = {
    "pattern1":65  ,
    "pattern2":110 ,
    "pattern3":30  ,
    "pattern4":155 ,
    "pattern5":200 ,
    "pattern6":1900 ,
    "pattern7":1643 ,
    "pattern8":1386
}

#name_plomblem_minimize
model =LpProblem("Cutting Stock_U" ,LpMinimize)

#decision variable
x =LpVariable.dict("x",pattern,lowBound=0 ,cat =LpInteger)

#objective function
model += lpSum(x[i]*unitcost_steel for i in pattern)
#model += lpSum(x[i]*loss_pattern[i] for i in pattern)

#constrain
for j in name_work : 
  model += lpSum(x[i]*work_piece[i][j] for i in pattern) >=demand[j] #เงื่อนไขผลิตงานให้ได้มากกว่าหรือเท่ากับdemand

#solve
model.solve()
print(model)
print("Status Model:",LpStatus[model.status]) #check status model
print("Opjective Funtion [Min_Cost]  = " , value(model.objective) ,"Baht") #เเสดงค่าobjective function

#เเสดงค่าdecision variabe
sum=0
for v in model.variables():
  if v.varValue > 0 : 
    print("Cutting" ,v.name,"=",v.varValue,"เส้น")
    sum =sum +v.varValue  
print("Total Steel = " ,sum,"เส้น")

d=[] #list decistion variable
for v in model.variables():
   d.append(v.varValue )
w=np.array(d)

l=[] #list loss_pattern
for i in loss_pattern.values():
  l.append(i)
q=np.array(l)

print("Total Loss =",np.sum(w*q),"mm") #เเสดงค่า loss

#เก็บlistชิ้นงาน

p1=[]
p2=[]
p3=[]
p4=[]

for i in work_piece.values():
  p1.append(i["202-05"])
  p2.append(i["205-05"])
  p3.append(i["210-05"])
  p4.append(i["240-17"])

p_202_05 =np.array(p1)
p_205_05 =np.array(p2)
p_210_05 =np.array(p3)
p_240_17 =np.array(p4)

#เเสดงค่าจำนวนชิ้นงาน
print("Number of [202-05] =",np.sum(p_202_05*w),"pieces" )
print("Number of [205-05] =",np.sum(p_205_05*w),"pieces")
print("Number of [210-05] =",np.sum(p_210_05*w),"pieces" )
print("Number of [240-17] =",np.sum(p_240_17*w),"pieces" )

# %% [markdown]
# #รูปเเบบการตัดเหล็กฉาก

# %%
length = [1870,2105,2335] #เหล็กฉาก
L = 6000

n = [int(L/x) for x in length]
m = [L - j*length[i] for i,j in enumerate(n)]

print(f'จำนวนชิ้นงานเริ่มต้น :{n}')
print(f'เศษเหลือเริ่มต้น : {m}')

for i, j in enumerate(length): 
  for x in range(n[i], 0, -1):
    print(f':: index = {i} ความยาวชิ้นงาน = {j}  จำนวนชิ้นที่ตัด = {x}  เศษเหลือ = {L - x*j}')
    for a, b in enumerate(length):
      if a != i:
        for y in range(1, n[a]):
          if L - x*j >= b*y:
            print('>>', y,"ชิ้น",b,"mm","เศษเหลือ =", L - x*j - b*y) 
            for c, d in enumerate(length):
                for z in range(1, n[c]): 
                  if  L - x*j - b*y >=  d*z :
                    print('>>>', z,"ชิ้น",d,"mm","เศษเหลือ =", L - x*j - b*y-d*z)
# Out:
# จำนวนชิ้นงานเริ่มต้น :[3, 2, 2]
# เศษเหลือเริ่มต้น : [390, 1790, 1330]
# :: index = 0 ความยาวชิ้นงาน = 1870  จำนวนชิ้นที่ตัด = 3  เศษเหลือ = 390
# :: index = 0 ความยาวชิ้นงาน = 1870  จำนวนชิ้นที่ตัด = 2  เศษเหลือ = 2260
# >> 1 ชิ้น 2105 mm เศษเหลือ = 155
# :: index = 0 ความยาวชิ้นงาน = 1870  จำนวนชิ้นที่ตัด = 1  เศษเหลือ = 4130
# >> 1 ชิ้น 2105 mm เศษเหลือ = 2025
# >>> 1 ชิ้น 1870 mm เศษเหลือ = 155
# >> 1 ชิ้น 2335 mm เศษเหลือ = 1795
# :: index = 1 ความยาวชิ้นงาน = 2105  จำนวนชิ้นที่ตัด = 2  เศษเหลือ = 1790
# :: index = 1 ความยาวชิ้นงาน = 2105  จำนวนชิ้นที่ตัด = 1  เศษเหลือ = 3895
# >> 1 ชิ้น 1870 mm เศษเหลือ = 2025
# >>> 1 ชิ้น 1870 mm เศษเหลือ = 155
# >> 2 ชิ้น 1870 mm เศษเหลือ = 155
# >> 1 ชิ้น 2335 mm เศษเหลือ = 1560
# :: index = 2 ความยาวชิ้นงาน = 2335  จำนวนชิ้นที่ตัด = 2  เศษเหลือ = 1330
# :: index = 2 ความยาวชิ้นงาน = 2335  จำนวนชิ้นที่ตัด = 1  เศษเหลือ = 3665
# >> 1 ชิ้น 1870 mm เศษเหลือ = 1795
# >> 1 ชิ้น 2105 mm เศษเหลือ = 1560

# %% [markdown]
# #เหล็กฉาก

# %%
# (new) MinCost ฉาก(input)
from pulp import *  
import pandas as pd 
import numpy as np 

#set
pattern = ["pattern1","pattern2","pattern3","pattern4","pattern5","pattern6"]
name_work = ["205-04","210-04","240-15"]

#parameter
unitcost_steel = int(input("unitcost_steel:"))
length = {"205-04" :1870 ,"210-04" :2105 ,"240-15":2335 }  

demand= {
    "205-04" : int(input("Demand 205-04:")) ,
    "210-04" : int(input("Demand 210-04:")) ,
    "240-15" : int(input("Demand 240-15:")) 
}
work_piece ={
    "pattern1":{"205-04":3 ,"210-04":0 ,"240-15":0},
    "pattern2":{"205-04":2 ,"210-04":1 ,"240-15":0},
    "pattern3":{"205-04":0 ,"210-04":2 ,"240-15":0},
    "pattern4":{"205-04":0 ,"210-04":0 ,"240-15":2},
    "pattern5":{"205-04":1 ,"210-04":0 ,"240-15":1},
    "pattern6":{"205-04":0 ,"210-04":1 ,"240-15":1},
 }
loss_pattern = {
    "pattern1":390 ,
    "pattern2":155 ,
    "pattern3":1790 ,
    "pattern4":1330 ,
    "pattern5":1795 ,
    "pattern6":1560
}

#name_model_minimize
model =LpProblem("Cutting Stock_L" ,LpMinimize)

#decision variable
x =LpVariable.dict("x",pattern,lowBound=0 ,cat =LpInteger)

#objective function
model += lpSum(x[i]*unitcost_steel for i in pattern)
#model += lpSum(x[i]*loss_pattern[i] for i in pattern)

#constrain
for j in name_work : 
  model += lpSum(x[i]*work_piece[i][j] for i in pattern) >=demand[j]

model.solve()
print(model)
print("Status Model:",LpStatus[model.status])
print("Opjective Funtion [Min_Cost]  = " , value(model.objective) ,"Baht")

#เเสดงค่า decision Variable
sum=0
for v in model.variables():
  if v.varValue > 0 : 
    print(v.name,"=",v.varValue,"เส้น")
    sum =sum +v.varValue  
print("Total Steel = " ,sum,"เส้น")  

d=[] #list decistion variable
for v in model.variables():
   d.append(v.varValue )
w=np.array(d)

l=[] #list loss_pattern
for i in loss_pattern.values():
  l.append(i)
q=np.array(l)

print("Total Loss =",np.sum(w*q),"mm") #เเสดงค่า loss

#เก็บlistชิ้นงาน
p1=[]
p2=[]
p3=[]

for i in work_piece.values():
  p1.append(i["205-04"])
  p2.append(i["210-04"])
  p3.append(i["240-15"])

p_205_04 =np.array(p1)
p_210_04 =np.array(p2)
p_240_15 =np.array(p3)

#เเสดงค่าจำนวนชิ้นงาน
print("Number of [205-04] =",np.sum(p_205_04*w),"pieces" )
print("Number of [210-04] =",np.sum(p_210_04*w),"pieces")
print("Number of [240-15] =",np.sum(p_240_15*w),"pieces" )
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-629b7f5b14ce> in <module>
#       1 # (new) MinCost ฉาก(input)
# ----> 2 from pulp import *
#       3 import pandas as pd
#       4 import numpy as np
#       5
#
# ModuleNotFoundError: No module named 'pulp'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
#(ole) Min Cost เหล็กราง 
from pulp import *  
import pandas as pd 
import numpy as np 

#set
pattern = ["pattern1","pattern2","pattern3","pattern4","pattern5","pattern6","pattern7","pattern8"]
name_work = ["202-05","205-05","210-05","240-17"]

#parameter
unitcost_steel =int(input("unitcost_steel:"))
length ={"202-05":1995,"205-05":1950, "210-05":2075,"240-17":2332}

demand= {
    "202-05" : int(input("Demand 202-05 :")) ,
    "205-05" : int(input("Demand 205-05 :")) ,
    "210-05" : int(input("Demand 210-05 :")),
    "240-17" : int(input("Demand 240-17 :"))
}
work_piece ={
    "pattern1":{"202-05":3 ,"205-05":0 ,"210-05":0 ,"240-17":0},

    "pattern2":{"202-05":2 ,"205-05":1 ,"210-05":0 ,"240-17":0},

    "pattern3":{"202-05":1 ,"205-05":1 ,"210-05":1 ,"240-17":0},

    "pattern4":{"202-05":1 ,"205-05":2 ,"210-05":0 ,"240-17":0},

    "pattern5":{"202-05":0 ,"205-05":3 ,"210-05":0 ,"240-17":0},

    "pattern6":{"202-05":0 ,"205-05":0 ,"210-05":2 ,"240-17":0},

    "pattern7":{"202-05":0 ,"205-05":0 ,"210-05":1 ,"240-17":1},

    "pattern8":{"202-05":0 ,"205-05":0 ,"210-05":0 ,"240-17":2}
 }

loss_pattern = {
    "pattern1":65  ,
    "pattern2":110 ,
    "pattern3":30  ,
    "pattern4":155 ,
    "pattern5":200 ,
    "pattern6":1900 ,
    "pattern7":1643 ,
    "pattern8":1386
}

#name_plomblem_minimize
model =LpProblem("Cutting Stock_U" ,LpMinimize)

#decision variable
x =LpVariable.dict("x",pattern,lowBound=0 ,cat =LpInteger)

#objective function
model += lpSum(x[i]*unitcost_steel for i in pattern)
#model += lpSum(x[i]*loss_pattern[i] for i in pattern)

#constrain
for j in name_work : 
  model += lpSum(x[i]*work_piece[i][j] for i in pattern) >=demand[j] #เงื่อนไขผลิตงานให้ได้มากกว่าหรือเท่ากับdemand

#solve
model.solve()
print(model)
print("Status Model:",LpStatus[model.status]) #check status model
print("Opjective Funtion [Min_Cost]  = " , value(model.objective) ,"Baht") #เเสดงค่าobjective function

#เเสดงค่าdecision variabe
sum=0
for v in model.variables():
  if v.varValue > 0 : 
    print("Cutting" ,v.name,"=",v.varValue,"เส้น")
    sum =sum +v.varValue  
print("Total Steel = " ,sum,"เส้น")

d=[] #list decistion variable
for v in model.variables():
   d.append(v.varValue )
w=np.array(d)

l=[] #list loss_pattern
for i in loss_pattern.values():
  l.append(i)
q=np.array(l)

print("Total Loss =",np.sum(w*q),"mm") #เเสดงค่า loss

#เก็บlistชิ้นงาน

p1=[]
p2=[]
p3=[]
p4=[]

for i in work_piece.values():
  p1.append(i["202-05"])
  p2.append(i["205-05"])
  p3.append(i["210-05"])
  p4.append(i["240-17"])

p_202_05 =np.array(p1)
p_205_05 =np.array(p2)
p_210_05 =np.array(p3)
p_240_17 =np.array(p4)

#เเสดงค่าจำนวนชิ้นงาน
print("Number of [202-05] =",np.sum(p_202_05*w),"pieces" )
print("Number of [205-05] =",np.sum(p_205_05*w),"pieces")
print("Number of [210-05] =",np.sum(p_210_05*w),"pieces" )
print("Number of [240-17] =",np.sum(p_240_17*w),"pieces" )
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-3-aa78635efb76> in <module>
#       1 #(ole) Min Cost เหล็กราง
# ----> 2 from pulp import *
#       3 import pandas as pd
#       4 import numpy as np
#       5
#
# ModuleNotFoundError: No module named 'pulp'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------
